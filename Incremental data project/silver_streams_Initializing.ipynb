# %% [markdown]
# ###sliver streams start

# %%
# %run "../Incremental_Loading_project_Formula1_race_data/Incremental data project/silver_streams_Initializing"

# %%
Silver_circuits_instance = Silver_circuits("circuits")
Silver_circuits_instance.process()

# %%
Silver_lap_times_instance = Silver_lap_times("lap_times")
Silver_lap_times_instance.process()

# %%
Silver_drivers_instance = Silver_drivers("drivers")
Silver_drivers_instance.process()

# %%
Silver_constructors_instance = Silver_constructors("constructors")
Silver_constructors_instance.process()

# %%
Silver_pit_stops_instance = Silver_pit_stops("pit_stops")
Silver_pit_stops_instance.process()

# %%
Silver_qualifying_instance = Silver_qualifying("qualifying")
Silver_qualifying_instance.process()

# %%
Silver_races_instance = Silver_races("races")
Silver_races_instance.process()

# %%
Silver_results_instance = Silver_results("results")
Silver_results_instance.process()
